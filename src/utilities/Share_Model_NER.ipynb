# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install huggingface_hub
# !pip install flair
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# !sudo apt-get install git-lfs
# !git lfs install
# !pip install piraye

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
# !git config --global credential.helper store

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
from huggingface_hub import Repository
repo = Repository(local_dir = '/content/persain-flair-ner', clone_from='hamedkhaledi/persain-flair-ner')
repo.git_pull()
# Out:
# Cloning https://huggingface.co/hamedkhaledi/persain-flair-ner into local empty directory.
# Download file pytorch_model.bin:   0%|          | 15.6k/396M [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/396M [00:00<?, ?B/s]

# %%
import torch
loaded_model = torch.load("/content/drive/MyDrive/project/data/ner/model2/final-model.pt")
print(loaded_model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-32c422825e3f> in <module>()
#       1 import torch
# ----> 2 loaded_model = torch.load("/content/drive/MyDrive/project/data/ner/model2/final-model.pt")
#       3 print(loaded_model)
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     605                     opened_file.seek(orig_position)
#     606                     return torch.jit.load(opened_file)
# --> 607                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     608         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     609
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
# ...

# %%
# !cp /content/drive/MyDrive/project/data/ner/model2/final-model.pt /content/persain-flair-ner/pytorch_model.bin
# !cp /content/drive/MyDrive/project/data/ner/model2/loss.tsv /content/persain-flair-ner
# !cp /content/drive/MyDrive/project/data/ner/model2/training.log /content/persain-flair-ner

# %%
repo.git_add("*",auto_lfs_track=True)
repo.push_to_hub(commit_message = "update model 40 epochs")
# Out:
# Upload file pytorch_model.bin:   0%|          | 32.0k/396M [00:00<?, ?B/s]
# To https://huggingface.co/hamedkhaledi/persain-flair-ner
#    bc49a95..f0cadde  main -> main
# 'https://huggingface.co/hamedkhaledi/persain-flair-ner/commit/f0caddea6fb569a4f10e08ba03a266cdb68e987e'

# %%
from flair.models import SequenceTagger
from flair.data import Sentence

tagger = SequenceTagger.load("hamedkhaledi/persain-flair-upos")
# create example sentence
sentence = Sentence(' من  نیویورک رو دوست دارم')
# predict tags and print
tagger.predict(sentence)

print(sentence.to_tagged_string())
# Out:
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# 2022-04-03 22:09:02,868 loading file /root/.flair/models/persain-flair-upos/d94b55c2ab57d80175948952be4e9fa06848a8e7e46cd7956b487895295713b9.5f354d57abbc3f496214fcc2b45f096f5f358902606179cd3dadc76048c344e6
# من <PRON> نیویورک <NOUN> رو <PART> دوست <NOUN> دارم <VERB>
